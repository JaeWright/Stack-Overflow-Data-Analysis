# %% [markdown]
# Introduction
#
# This report is centered on the Stack Overflow Developer Survey 2020 which is a survey held by Stack Overflow that gathers information from over 60,000 software developers from 186 countries, to analyze different aspects of the “developer experience”. As computer science students this topic immediately intrigued us, as the data alone helped us gather some insight into what it is truly like being a software developer directly from people who have been in the role for years, to even decades. However, our group also hopes to look at different aspects such as the representation of People of Color (POC) and their treatment, how developers differ by location, how education affects salary, and many other aspects to help gather even deeper insights into the software development community.
# 	Our group members are Sadiq Hussain, Nathan Weir, and Jaelen Wright. As a group, everyone participated in writing the code used for the analysis questions, and listed below are each member’s individual responsibilities:
#
# Sadiq Hussain – Question 1 and 3, Collaboration on the Document
#
# Nathan Weir – Question 2 and 5, Collaboration on the Document
#
# Jaelen Wright – Question 4, Collaboration on the Document

# %% [markdown]
# Description of Data
#
# Respondent, - Randomized respondent ID number (not in order of survey response time)
#
# MainBranch, - Which of the following options best describes you today? Here, by "developer" we mean "someone who writes code."
#
# Hobbyist, - Do you code as a hobby?
#
# Age, - What is your age (in years)?
#
# Age1stCode, - At what age did you write your first line of code or program?
#
# CompFreq, - Is that compensation weekly, monthly, or yearly?
#
# CompTotal, - What is your current total compensation?
#
# ConvertedComp, - Salary converted to annual USD salaries using the exchange rate on 2020-02-19, assuming 12 working months and
# 50 working weeks.
#
# Country, - Where do you live?
#
# CurrencyDesc, - Which currency do you use day-to-day?
#
# CurrencySymbol, - Which currency do you use day-to-day?
#
# DatabaseDesireNextYear, - Which database environments have you done extensive development work in over the past year, and which do you want to work in over the next year?
#
# DatabaseWorkedWith, - Which database environments have you done extensive development work in over the past year, and which do you want to work in over the next year?
#
# DevType, - What type of Developer are you? (software, front end, back end, etc)
#
# EdLevel, - What is the highest level of formal education that you’ve completed?
#
# Employment, - What is your current employment status?
#
# Ethnicity, - What is your ethnicity?
#
# Gender, - Which of the following describe you, if any? Please check all that apply. If you prefer not to answer, you may leave this question blank.
#
# JobFactors, - Imagine that you are deciding between two job offers with the same compensation, benefits, and location. Of the following factors, which 3 are MOST important to you?
#
# JobSat, - How satisfied are you with your current job? (If you work multiple jobs, answer for the one you spend the most hours on.)
#
# JobSeek, - Which of the following best describes your current job-seeking status?
#
# LanguageDesireNextYear, - Which programming, scripting, and markup languages have you done extensive development work in over
# the past year, and which do you want to work in over the next year? (If you both worked with the language and want to continue to do so, please check both boxes in that row.)
#
# LanguageWorkedWith, - Which programming, scripting, and markup languages have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the language and want to continue to do so, please check both boxes in that row.)
#
# MiscTechDesireNextYear, - Which other frameworks, libraries, and tools have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the framework and want to continue to do so, please check both boxes in that row.)
#
# MiscTechWorkedWith, - Which other frameworks, libraries, and tools have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the framework and want to continue to do so, please check both boxes in that row.)
#
# NEWCollabToolsDesireNextYear, - Which collaboration tools have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you worked with the tool and want to continue to do so, please check both boxes in that row.)
#
# NEWCollabToolsWorkedWith, - Which collaboration tools have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you worked with the tool and want to continue to do so, please check both boxes in that row.)
#
# NEWDevOps, - Does your company have a dedicated DevOps person?
#
# NEWDevOpsImpt, - How important is the practice of DevOps to scaling software development?
#
# NEWEdImpt, - How important is a formal education, such as a university degree in computer science, to your career?
#
# NEWJobHunt, - In general, what drives you to look for a new job? Select all that apply.
#
# NEWJobHuntResearch, - When job searching, how do you learn more about a company? Select all that apply.
#
# NEWLearn, - How frequently do you learn a new language or framework?
#
# NEWOffTopic, - Do you think Stack Overflow should relax restrictions on what is considered “off-topic”?
#
# NEWOnboardGood, - Do you think your company has a good onboarding process? (By onboarding, we mean the structured process of getting you settled in to your new role at a company)
#
# NEWOtherComms, - Are you a member of any other online developer communities?
#
# NEWOvertime, - How often do you work overtime or beyond the formal time expectation of your job?
#
# NEWPurchaseResearch, - When buying a new tool or software, how do you discover and research available solutions? Select all that apply.
#
# NEWPurpleLink, - You search for a coding solution online and the first result link is purple because you already visited it. How do you feel?
#
# NEWSOSites, - Which of the following Stack Overflow sites have you visited? Select all that apply.
#
# NEWStuck, - What do you do when you get stuck on a problem? Select all that apply.
#
# OpSys, - What is the primary operating system in which you work?
#
# OrgSize, - Approximately how many people are employed by the company or organization you currently work for?
#
# PlatformDesireNextYear, - Which platforms have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the platform and want to continue to do so, please check both boxes in that row.)
#
# PlatformWorkedWith, - Which platforms have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the platform and want to continue to do so, please check both boxes in that row.)
#
# PurchaseWhat, - What level of influence do you, personally, have over new technology purchases at your organization?
#
# Sexuality, - Which of the following describe you, if any? Please check all that apply. If you prefer not to answer, you may leave this question blank.
#
# SOAccount, - Do you have a Stack Overflow account?
#
# SOComm, - Do you consider yourself a member of the Stack Overflow community?
#
# SOPartFreq, - How frequently would you say you participate in Q&A on Stack Overflow? By participate we mean ask, answer, vote for, or comment on questions.
#
# SOVisitFreq, - How frequently would you say you visit Stack Overflow?
#
# SurveyEase, - How easy or difficult was this survey to complete?
#
# SurveyLength, - How do you feel about the length of the survey this year?
#
# Trans, - Are you transgender?
#
# UndergradMajor, - What was your primary field of study?
#
# WebframeDesireNextYear, - Which web frameworks have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the framework and want to continue to do so, please check both boxes in that row.)
#
# WebframeWorkedWith, - Which web frameworks have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the framework and want to continue to do so, please check both boxes in that row.)
#
# WelcomeChange, - Compared to last year, how welcome do you feel on Stack Overflow?
#
# WorkWeekHrs, - On average, how many hours per week do you work? Please enter a whole number in the box.
#
# YearsCode, - Including any education, how many years have you been coding in total?
#
# YearsCodePro, - NOT including education, how many years have you coded professionally (as a part of your work)?

# %% [markdown]
# Analysis of the Data
#
# Upon further looking at the data and responses by themselves, it has become apparent that the data, while organized, will need to be cleaned up for the sake of gathering accurate results. This is due to many entries being optional such as the ones for sexuality, ethnicity, and age, where they could choose to select non-applicable (NA) instead if answering. While this doesn’t affect the answers where we are just looking to see how many people answered a specific question, it becomes a problem when attempting to calculate using numerical data to draw conclusions and correlations while keeping the data consistent. This can be solved by replacing the NA in these sections with a 0, so that they will allow us to calculate the overall values without affecting the values or getting any coding errors. The rest of the data was received such that the responses were multiple-choice, allowing us to avoid having to clean it up.
#     Overall, the data itself was of very high quality, as even the multiple-choice responses allowed for multiple selections and offered a wide variety of choices to gather data that was as accurate as possible. This meant that we will be able to use the data to look at very specific demographics for our analysis questions without having to account for other groups being mixed in.

# %% [markdown]
# Exploratory Data Analysis

# %%
#importing used libraries
import csv
import re
from functools import reduce
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# this aux function reads the CSV file and returns the data in a Python dictionary
def get_data_csv():
    collection = []
    with open('survey_results_public.csv', 'r') as f:
        for line in csv.DictReader(f):
            collection.append(line)
        return collection
    
def get_desc_csv():
    collection = []
    with open('survey_results_schema.csv', 'r') as f:
        for line in csv.DictReader(f):
            collection.append(line)
        return collection
        
# the data    
data = get_data_csv()
desc = get_desc_csv()

# %% [markdown]
# Question 1: How are POC represented?

# %%
survey = pd.read_csv("survey_results_public.csv")
survey['Ethnicity']
# Out:
# 0        White or of European descent
# 1                                 NaN
# 2                                 NaN
# 3        White or of European descent
# 4        White or of European descent
#                      ...
# 64456                             NaN
# 64457                             NaN
# 64458                             NaN
# 64459                             NaN
# 64460                             NaN
# Name: Ethnicity, Length: 64461, dtype: object

# %%
#getting comp avergaes
def average_salary(entry, salary):
 
    return salary + entry

allSalaries = survey[survey['ConvertedComp'].notna()]
globalComps = reduce(average_salary, allSalaries['ConvertedComp'], 0.0)
globalAverageComps = globalComps/len(allSalaries.index)
globalAverageComps
# Out:
# 103756.05014961446

# %%
#getting non poc rows whehre comp is given
#need to bhe optimised this was done in a rush
nonPOCloc = survey['Ethnicity'] == "White or of European descent"
nonPOC = survey[nonPOCloc]
forWhiteSalary = nonPOC[nonPOC['ConvertedComp'].notna()]

# %%
#getting average non POC compensation
totalWhiteComps = reduce(average_salary, forWhiteSalary['ConvertedComp'], 0.0)
averageWhiteComp = totalWhiteComps/len(forWhiteSalary.index)
averageWhiteComp
# Out:
# 119493.95560122348

# %%
#Getting average POC compensation
pocComps = allSalaries[allSalaries['Ethnicity'] != "White or of European descent"]
averagePOCComps = reduce(average_salary, pocComps['ConvertedComp'], 0.0)
averagePOCComps = averagePOCComps/len(pocComps.index)
averagePOCComps
# Out:
# 79948.94100636206

# %%
# global average working hours
workHoursdf = survey[survey['WorkWeekHrs'].notna()]
globalAvgWork = reduce(lambda x,y: x+y, workHoursdf['WorkWeekHrs'], 0)
globalAvgWork = globalAvgWork/len(workHoursdf.index)
globalAvgWork
# Out:
# 40.782173999014546

# %%
#getting non POC average work hours
whiteHoursdf = workHoursdf[workHoursdf['Ethnicity'] == "White or of European descent"]
whiteWorkHours = reduce(lambda x,y: x+y, whiteHoursdf['WorkWeekHrs'], 0)
whiteWorkHours = whiteWorkHours/len(whiteHoursdf.index)
whiteWorkHours
# Out:
# 40.93628765269704

# %%
#gettign average POC work hours
pocWorkHoursdf = workHoursdf[workHoursdf['Ethnicity'] != "White or of European descent"]
pocHours = reduce(lambda x,y: x+y, pocWorkHoursdf['WorkWeekHrs'], 0)
pocHours = pocHours/len(pocWorkHoursdf.index)
pocHours
# Out:
# 40.57562278903189

# %%
#getting amounts of entries looked at
print(f"Amount of developers salaries looked at: {len(allSalaries.index)}")
print(f"Non-POC salaries looked at:              {len(forWhiteSalary.index)}")
print(f"POC salaries looked at:                  {len(pocComps.index)}")

print("\n")

print(f"Amount of developers work hours looked at: {len(workHoursdf.index)}")
print(f"Non-POC work hours looked at:              {len(whiteHoursdf.index)}")
print(f"POC work hours looked at:                  {len(pocWorkHoursdf.index)}")
# Out:
# Amount of developers salaries looked at: 34756
# Non-POC salaries looked at:              20924
# POC salaries looked at:                  13832
#
#
# Amount of developers work hours looked at: 41151
# Non-POC work hours looked at:              23567
# POC work hours looked at:                  17584

# %% [markdown]
# Based on the data we werea able to get. POC and Non-POC developers seem to work very similar hours. Averaging a basic 40 hour work week. The big difference comes in the average salaries. POC developers made about $40,000 less than non-POC. This is a very big difference considering they work about the same amount fo hours. Need to keep in mind however, only about half of the devlopers were screened for each question, the rest didnt want to share. this could bridge the gap between the work hours, but there is no doubt about the difference in salary.
#
# More research needs to be made about different factors such as position worked and the location each developer works in.

# %%
import matplotlib.pyplot as plt

#Filtering and cleaning survey to our needs and to remove unneccesary data
filteredSurvey = survey[survey['WorkWeekHrs'].notna() & survey['ConvertedComp'].notna()]
#Added limitations to deal with outlires
filteredSurvey = filteredSurvey[(filteredSurvey['WorkWeekHrs']<80) & (filteredSurvey['ConvertedComp']>10000)]

#Plotting POC
pocValues = filteredSurvey[filteredSurvey['Ethnicity']  != "White or of European descent"]

ax1=pocValues.plot(kind='scatter', figsize=(15,8), x="WorkWeekHrs",y="ConvertedComp", color = 'b', label="POC", title="Total Compensation vs Weekly Work Hours")


#Plotting non-POC
whiteValues = filteredSurvey[filteredSurvey['Ethnicity']  == "White or of European descent"]

whiteValues.plot(kind='scatter', figsize=(15,8), x="WorkWeekHrs",y="ConvertedComp",color = 'r', label = "Non-POC", title="Total Compensation vs Weekly Work Hours")
plt.legend()

# %% [markdown]
# The gives an insight into our previously found results for the average compensations and work horus of POC adn Non-POC developers. We can see that their is a substantial difference between the amount developers observed for each category. Their is almost double the amount of non-POC developers, which could be a reason for the difference in compensation averages. We also see however, that there is a very slight right skew to these distributions though they are fairly normally distributed. We also see that the Non-POC points are also more abundant in the average area of 35 hours and around 75-100k compensation. And though only by a little bit, the non-POC are lisghtly more abundant in the bottom left hand corner of the graph indicating the least amoutn fo work hours and least compensation. This may give insight into the hobbies of POC vs non-POC as the lower end compensation workers may see programmiugn as more ofa hobby and therefore dont care to work long hours or get more pay.

# %% [markdown]
# Question 2: What are the work hours like for each scale of business(eg. Large, small, medium)? Does overtime vary depending on the scale of the business? How are the developers job satisfaction affected by these factors?

# %%
# Defines the size of each organization.

# List of all elements with an OrgSize with 1,000 or more employees.
largeOrgSize = list(filter(lambda i: (i['OrgSize']=='1,000 to 4,999 employees') or
                                     (i['OrgSize']=='5,000 to 9,999 employees') or
                                     (i['OrgSize']=='10,000 or more employees'), data))

# List of all elements with an OrgSize between 20 and 999 employees
mediumOrgSize = list(filter(lambda i: (i['OrgSize']=='500 to 999 employees') or
                                      (i['OrgSize']=='100 to 499 employees') or
                                      (i['OrgSize']=='20 to 99 employees'), data))

# List of all elements with an OrgSize between 2 and 19 employees
smallOrgSize = list(filter(lambda i: (i['OrgSize']=='10 to 19 employees') or 
                                     (i['OrgSize']=='2 to 9 employees'), data))

# List of all elements with a single employee
soloOrgSize = list(filter(lambda i: (i['OrgSize']=='Just me - I am a freelancer, sole proprietor, etc.'), data))

# %% [markdown]
# Next, we will find the average (mean) hours worked per organization size.
# This will answer the question: "What are the work hours like for each scale of business(eg. Large, small, medium)?"

# %%
# Prints the mean hours worked per organization size.

import statistics

hoursLargeMean = list(map(lambda x : x['WorkWeekHrs'], largeOrgSize)) # Get the work week hours for the "large organization" size
hoursLargeMean = list(filter(lambda i: i!='NA', hoursLargeMean))      # Remove all instances of 'NA'
hoursLargeMean = list(map(lambda x : float(x), hoursLargeMean))       # Convert the hours to numeric
meanLarge = statistics.mean(hoursLargeMean)                           # Get mean

hoursMediumMean = list(map(lambda x : x['WorkWeekHrs'], mediumOrgSize)) # Same method but for the "medium organization" size
hoursMediumMean = list(filter(lambda i: i!='NA', hoursMediumMean))
hoursMediumMean = list(map(lambda x : float(x), hoursMediumMean))
meanMedium = statistics.mean(hoursMediumMean)

hoursSmallmean = list(map(lambda x : x['WorkWeekHrs'], smallOrgSize)) # Same method but for the "small organization" size
hoursSmallmean = list(filter(lambda i: i!='NA', hoursSmallmean))
hoursSmallmean = list(map(lambda x : float(x), hoursSmallmean))
meanSmall = statistics.mean(hoursSmallmean)

hoursSoloMean = list(map(lambda x : x['WorkWeekHrs'], soloOrgSize)) #S ame method but for the "solo organization" size
hoursSoloMean = list(filter(lambda i: i!='NA', hoursSoloMean))
hoursSoloMean = list(map(lambda x : float(x), hoursSoloMean))
meanSolo = statistics.mean(hoursSoloMean)

# Print out results
print(f"- Work hours per week from respondents in a 'large organization' are on average {round(meanLarge, 2)},")
print(f"- Work hours per week from respondents in a 'medium organization' are on average {round(meanMedium, 2)},")
print(f"- Work hours per week from respondents in a 'small organization' are on average {round(meanSmall, 2)},")
print(f"- Work hours per week from respondents in a 'solo organization' are on average {round(meanSolo, 2)}.")
print('\nWork hours slightly decreases on average as the size of the organization decreases.\n')
# Out:
# - Work hours per week from respondents in a 'large organization' are on average 41.04,
# - Work hours per week from respondents in a 'medium organization' are on average 40.83,
# - Work hours per week from respondents in a 'small organization' are on average 40.6,
# - Work hours per week from respondents in a 'solo organization' are on average 39.78.
#
# Work hours slightly decreases on average as the size of the organization decreases.

# %% [markdown]
# Next, we will find the most common response from respondants about their overtime work hours per organization size.
# This will answer the question: "Does overtime vary depending on the scale of the business?"

# %%
# Prints the most common response from respondants about their overtime work hours per organization size.

# Returns the most frequent value in a list.
def most_frequent(x):
    return max(set(x), key = x.count)

frequentLargeOvertimeList = list(map(lambda x : x['NEWOvertime'], largeOrgSize))        # Get the overtime responses for the "large organization" size
frequentLargeOvertimeList = list(filter(lambda i: i!='NA', frequentLargeOvertimeList))  # Remove all instances of 'NA'
frequentLargeOvertime = most_frequent(frequentLargeOvertimeList)                        # Get the most frequent response

frequentMediumOvertimeList = list(map(lambda x : x['NEWOvertime'], mediumOrgSize))      # Same method but for the "medium organization" size
frequentMediumOvertimeList = list(filter(lambda i: i!='NA', frequentMediumOvertimeList))
frequentMediumOvertime = most_frequent(frequentMediumOvertimeList)

frequentSmallOvertimeList = list(map(lambda x : x['NEWOvertime'], smallOrgSize))        # Same method but for the "small organization" size
frequentSmallOvertimeList = list(filter(lambda i: i!='NA', frequentSmallOvertimeList))
frequentSmallOvertime = most_frequent(frequentSmallOvertimeList)

frequentSoloOvertimeList = list(map(lambda x : x['NEWOvertime'], soloOrgSize))          # Same method but for the "solo organization" size
frequentSoloOvertimeList = list(filter(lambda i: i!='NA', frequentSoloOvertimeList))
frequentSoloOvertime = most_frequent(frequentSoloOvertimeList)

# Print out results
print(f"- Overtime from respondents in a 'large organization' are most commonly '{frequentLargeOvertime}',")
print(f"- Overtime from respondents in a 'medium organization' are most commonly '{frequentMediumOvertime}',")
print(f"- Overtime from respondents in a 'small organization' are most commonly '{frequentSmallOvertime}',")
print(f"- Overtime from respondents in a 'solo organization' are most commonly '{frequentSoloOvertime}'.")
print('\nOvertime increases as the size of the organization decreases.\n')
# Out:
# - Overtime from respondents in a 'large organization' are most commonly 'Sometimes: 1-2 days per month but less than weekly',
# - Overtime from respondents in a 'medium organization' are most commonly 'Sometimes: 1-2 days per month but less than weekly',
# - Overtime from respondents in a 'small organization' are most commonly 'Often: 1-2 days per week or more',
# - Overtime from respondents in a 'solo organization' are most commonly 'Often: 1-2 days per week or more'.
#
# Overtime increases as the size of the organization decreases.

# %% [markdown]
# Next, we will find the most common response from respondants about their job satisfaction.
# This will answer the question: "How are the developers job satisfaction affected by these factors?"

# %%
# Prints the most common response from respondants about their job satisfaction.

frequentLargeSatisfactionList = list(map(lambda x : x['JobSat'], largeOrgSize)) # Get the job satisfaction responses for the "large organization" size
frequentLargeSatisfactionList = list(filter(lambda i: i!='NA', frequentLargeSatisfactionList)) # Remove all instances of 'NA'
frequentLargeSatisfaction = most_frequent(frequentLargeSatisfactionList) # Get the most frequent response.
#  See previous code cell for "most_frequent" function.

frequentMediumSatisfactionList = list(map(lambda x : x['JobSat'], mediumOrgSize)) # Same method but for the "medium organization" size
frequentMediumSatisfactionList = list(filter(lambda i: i!='NA', frequentMediumSatisfactionList))
frequentMediumSatisfaction = most_frequent(frequentMediumSatisfactionList)

frequentSmallSatisfactionList = list(map(lambda x : x['JobSat'], smallOrgSize)) # Same method but for the "small organization" size
frequentSmallSatisfactionList = list(filter(lambda i: i!='NA', frequentSmallSatisfactionList))
frequentSmallSatisfaction = most_frequent(frequentSmallSatisfactionList)

frequentSoloSatisfactionList = list(map(lambda x : x['JobSat'], soloOrgSize)) # Same method but for the "solo organization" size
frequentSoloSatisfactionList = list(filter(lambda i: i!='NA', frequentSoloSatisfactionList))
frequentSoloSatisfaction = most_frequent(frequentSoloSatisfactionList)

# Print out results
print(f"- Work satisfaction from respondents in a 'large organization' are most commonly '{frequentLargeSatisfaction}',")
print(f"- Work satisfaction from respondents in a 'medium organization' are most commonly '{frequentMediumSatisfaction}',")
print(f"- Work satisfaction from respondents in a 'small organization' are most commonly '{frequentSmallSatisfaction}',")
print(f"- Work satisfaction from respondents in a 'solo organization' are most commonly '{frequentSoloSatisfaction}'.")
print('\nWork satisfaction generally stays the same.\n')
# Out:
# - Work satisfaction from respondents in a 'large organization' are most commonly 'Very satisfied',
# - Work satisfaction from respondents in a 'medium organization' are most commonly 'Very satisfied',
# - Work satisfaction from respondents in a 'small organization' are most commonly 'Very satisfied',
# - Work satisfaction from respondents in a 'solo organization' are most commonly 'Very satisfied'.
#
# Work satisfaction generally stays the same.

# %% [markdown]
# To find some deeper information about the respondant's job satisfaction, we will find the percentage of people who are "very dissatisfied" and "very satisfied" with their job.
# This will help to answer the question: "How are the developers job satisfaction affected by these factors?"

# %%
# Prints the most average percentage of respondants who are "very dissatisfied" and "very satisfied" with their job.

# Divides the amount of people who are "very dissatisfied" by the length of the list of people in a "large organization".
percentageUnsatasfiedLarge = frequentLargeSatisfactionList.count('Very dissatisfied')/len(frequentLargeSatisfactionList)
# Converts the number into a percentage.
percentageUnsatasfiedLarge = percentageUnsatasfiedLarge*100

# Same method but for the "medium organization" size
percentageUnsatasfiedMedium = frequentMediumSatisfactionList.count('Very dissatisfied')/len(frequentMediumSatisfactionList)
percentageUnsatasfiedMedium = percentageUnsatasfiedMedium*100

# Same method but for the "small organization" size
percentageUnsatasfiedSmall = frequentSmallSatisfactionList.count('Very dissatisfied')/len(frequentSmallSatisfactionList)
percentageUnsatasfiedSmall = percentageUnsatasfiedSmall*100

# Same method but for the "solo organization" size
percentageUnsatasfiedSolo = frequentSoloSatisfactionList.count('Very dissatisfied')/len(frequentSoloSatisfactionList)
percentageUnsatasfiedSolo = percentageUnsatasfiedSolo*100

# Print out the results for people who are "very dissatisfied"
print(f"- Percentage of people 'very dissatisfied' with their work in a 'large organization' is '{percentageUnsatasfiedLarge}',")
print(f"- Percentage of people 'very dissatisfied' with their work in a 'medium organization' is '{percentageUnsatasfiedMedium}',")
print(f"- Percentage of people 'very dissatisfied' with their work in a 'small organization' is '{percentageUnsatasfiedSmall}',")
print(f"- Percentage of people 'very dissatisfied' with their work in a 'solo organization' is '{percentageUnsatasfiedSolo}'.")
print('\nThe percentage of people who are very dissatisfied with their work has a slight upwards trend as the size decreases.\n')

# Same method but for the people who are "very satisfied" in the "large organization" size
percentageSatasfiedLarge = frequentLargeSatisfactionList.count('Very satisfied')/len(frequentLargeSatisfactionList)
percentageSatasfiedLarge = percentageSatasfiedLarge*100

# Same method but for the people who are "very satisfied" in the "medium organization" size
percentageSatasfiedMedium = frequentMediumSatisfactionList.count('Very satisfied')/len(frequentMediumSatisfactionList)
percentageSatasfiedMedium = percentageSatasfiedMedium*100

# Same method but for the people who are "very satisfied" in the "small organization" size
percentageSatasfiedSmall = frequentSmallSatisfactionList.count('Very satisfied')/len(frequentSmallSatisfactionList)
percentageSatasfiedSmall = percentageSatasfiedSmall*100

# Same method but for the people who are "very satisfied" in the "solo organization" size
percentageSatasfiedSolo = frequentSoloSatisfactionList.count('Very satisfied')/len(frequentSoloSatisfactionList)
percentageSatasfiedSolo = percentageSatasfiedSolo*100

# Print out the results for people who are "very satisfied"
print(f"- Percentage of people 'very satisfied' with their work in a 'large organization' is '{percentageSatasfiedLarge}',")
print(f"- Percentage of people 'very satisfied' with their work in a 'medium organization' is '{percentageSatasfiedMedium}',")
print(f"- Percentage of people 'very satisfied' with their work in a 'small organization' is '{percentageSatasfiedSmall}',")
print(f"- Percentage of people 'very satisfied' with their work in a 'solo organization' is '{percentageSatasfiedSolo}'.")
print('\nThe percentage of people who are satasfied with their work also has a slight upwards trend as the size decreases, on a slightly larger upwards trend than people very dissatisfied.')
# Out:
# - Percentage of people 'very dissatisfied' with their work in a 'large organization' is '7.993117472235258',
# - Percentage of people 'very dissatisfied' with their work in a 'medium organization' is '7.92074434749072',
# - Percentage of people 'very dissatisfied' with their work in a 'small organization' is '9.36435201503936',
# - Percentage of people 'very dissatisfied' with their work in a 'solo organization' is '9.132629646626892'.
#
# The percentage of people who are very dissatisfied with their work has a slight upwards trend as the size decreases.
#
# - Percentage of people 'very satisfied' with their work in a 'large organization' is '31.886438291881745',
# - Percentage of people 'very satisfied' with their work in a 'medium organization' is '32.23256038181555',
# - Percentage of people 'very satisfied' with their work in a 'small organization' is '32.44037128422042',
# - Percentage of people 'very satisfied' with their work in a 'solo organization' is '36.255162918770075'.
# ...

# %% [markdown]
# Question 3:

# %%
survey = pd.read_csv("survey_results_public.csv")
jobHunters = survey[survey['NEWJobHunt'].notna()]
jobHunters['NEWJobHunt']
# Out:
# 3        Curious about other opportunities;Wanting to w...
# 6        Better compensation;Growth or leadership oppor...
# 7        Curious about other opportunities;Better compe...
# 8        Curious about other opportunities;Growth or le...
# 9        Curious about other opportunities;Better compe...
#                                ...
# 64111                                  Better compensation
# 64146                            Trouble with my teammates
# 64148    Having a bad day (or week or month) at work;Cu...
# 64152    Curious about other opportunities;Better compe...
# 64153    Curious about other opportunities;Better compe...
# Name: NEWJobHunt, Length: 42286, dtype: object

# %%
#Going to split each value by semi colons 
def splitter(value):
    valuesList = value.split(';')
    return valuesList
jobHunters['REASONS'] = jobHunters['NEWJobHunt'].apply(splitter)
# Out:
# /tmp/ipykernel_302/3602230688.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jobHunters['REASONS'] = jobHunters['NEWJobHunt'].apply(splitter)

# %%
jobHunters['REASONS']
# Out:
# 3        [Curious about other opportunities, Wanting to...
# 6        [Better compensation, Growth or leadership opp...
# 7        [Curious about other opportunities, Better com...
# 8        [Curious about other opportunities, Growth or ...
# 9        [Curious about other opportunities, Better com...
#                                ...
# 64111                                [Better compensation]
# 64146                          [Trouble with my teammates]
# 64148    [Having a bad day (or week or month) at work, ...
# 64152    [Curious about other opportunities, Better com...
# 64153    [Curious about other opportunities, Better com...
# Name: REASONS, Length: 42286, dtype: object

# %%
#counting amount of rows with each option
options = []
amounts = []

#fucntion to count the numebr of occurrences of all values found
def proportions(value):
    
    #looping through the list made for each row
    for option in value:
        
        #if option is already in the list jsut add to a the corresponding amount
        if option in options:
            amounts[options.index(option)] = amounts[options.index(option)] + 1
            
        #if the option is not in add it to the options list and give it an amount slot
        else:
            options.append(option)
            amounts.append(1)

jobHunters['REASONS'].apply(proportions)
print(options)
print(amounts)
# Out:
# ['Curious about other opportunities', 'Wanting to work with new technologies', 'Better compensation', 'Growth or leadership opportunities', 'Trouble with my direct manager', 'Trouble with leadership at my company', 'Better work/life balance', 'Looking to relocate', 'Having a bad day (or week or month) at work', 'Wanting to share accomplishments with a wider network', 'Trouble with my teammates', 'Just because']
# [24164, 24747, 29581, 22388, 7192, 11331, 20408, 11116, 8579, 4354, 4931, 5214]

# %%
#plotting values in pie chart
plt.pie(amounts, labels = options, radius = 10, autopct='%.0f%%')
plt.rcParams.update({'font.size': 55})
plt.title("Driving Factors to Look for new Job", bbox={'facecolor':'0.8', 'pad':25})
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Now going to look into which factors impact a developers decision 
#between 2 companies with same comp and benifits and location

factorDevs = survey[survey['JobFactors'].notna()]

factorDevs['JobFactors']
# Out:
# 0        Languages, frameworks, and other technologies ...
# 3        Flex time or a flexible schedule;Office enviro...
# 5        Diversity of the company or organization;Langu...
# 7        Remote work options;Opportunities for professi...
# 8        Diversity of the company or organization;Remot...
#                                ...
# 64146    Specific department or team I’d be working on;...
# 64148    Industry that I’d be working in;Languages, fra...
# 64150    Flex time or a flexible schedule;Languages, fr...
# 64152    Flex time or a flexible schedule;Languages, fr...
# 64153    Languages, frameworks, and other technologies ...
# Name: JobFactors, Length: 49349, dtype: object

# %%
#Splitting values from factors into easy to use list
factorDevs['FACTORS'] = factorDevs['JobFactors'].apply(lambda x: x.split(';'))


#Calculating amount of selections per option
options = []
amounts = []

factorDevs['FACTORS'].apply(proportions)
print(options)
print(amounts)
# Out:
# ['Languages, frameworks, and other technologies I’d be working with', 'Remote work options', 'Opportunities for professional development', 'Flex time or a flexible schedule', 'Office environment or company culture', 'Diversity of the company or organization', 'Family friendliness', 'How widely used or impactful my work output would be', 'Industry that I’d be working in', 'Financial performance or funding status of the company or organization', 'Specific department or team I’d be working on']
# [25334, 16411, 20421, 21656, 21981, 3387, 5986, 10277, 7574, 5892, 5805]
# /tmp/ipykernel_302/487622858.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   factorDevs['FACTORS'] = factorDevs['JobFactors'].apply(lambda x: x.split(';'))

# %%
#Plotting Factors values
colorOption = ['red', 'gold', 'yellowgreen', 'green', 'lightcoral', 'lightskyblue']
plt.pie(amounts, labels = options, radius = 10, autopct='%.0f%%',colors = colorOption )
plt.rcParams.update({'font.size': 55})
plt.title("Most Important Job Factors", bbox={'facecolor':'0.8', 'pad':25})
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# We can see and confirm from this graph the findings in the previous pie chart. We see that when compensation is taken out of the argument, the biggest factor developers look into when looking at jobs would be the technologies worked with, and the flexibility of the position, looking into things like flex time, and remote work. Company culture is also as we see in the graph, but logically speaking it also ties into the flexibility of the position, and the oppurtunities for growth. Company culture can dictate how the professional progression goes for its employees. For example could put heavier value on technical skills as opposed to soft skills, and that would decide wether a person whose analytically or socially smart progresses in said company.
#
# All in all we can see that the biggest thing that motivates developers to work for a certain position is the pay, and theirt ability to progress in that role. The tech industry is an ever evolving field, so it makes sence that developers would put great value into their own personal development.

# %% [markdown]
# Question 4: Does education level play a role in the career of a developer?

# %%
import statistics
#creating list of categories for each education level
education = list(map(lambda x : x['EdLevel'], data))
categories = sorted(set(education))

#finding indexes for all education levels
bachelor = list(filter(lambda i: (i['EdLevel']=='Bachelor’s degree (B.A., B.S., B.Eng., etc.)'),data))
master = list(filter(lambda i: (i['EdLevel']=='Master’s degree (M.A., M.S., M.Eng., MBA, etc.)'),data))
notCompleted = list(filter(lambda i: (i['EdLevel']=='I never completed any formal education'),data))
college = list(filter(lambda i: (i['EdLevel']=='Some college/university study without earning a degree'),data))
secondary = list(filter(lambda i: (i['EdLevel']=='Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)'),data))
doctoral = list(filter(lambda i: (i['EdLevel']=='Other doctoral degree (Ph.D., Ed.D., etc.)'),data))
associate = list(filter(lambda i: (i['EdLevel']=='Associate degree (A.A., A.S., etc.)'),data))
primary = list(filter(lambda i: (i['EdLevel']=='Primary/elementary school'),data))
pro = list(filter(lambda i: (i['EdLevel']=='Professional degree (JD, MD, etc.)'),data))
na = list(filter(lambda i: (i['EdLevel']=='NA'),data))

#cleaning up values, calculating means, and adding to list for sorting
means = []
aMean = list(map(lambda x : x['ConvertedComp'], associate))
aMean = list(filter(lambda i: i!='NA', aMean))
aMean = list(map(lambda x : float(x), aMean))
aMean = statistics.mean(aMean)
means.append(aMean)

bMean = list(map(lambda x : x['ConvertedComp'], bachelor))
bMean = list(filter(lambda i: i!='NA', bMean))
bMean = list(map(lambda x : float(x), bMean))
bMean = statistics.mean(bMean)
means.append(bMean)

ncMean = list(map(lambda x : x['ConvertedComp'], notCompleted))
ncMean = list(filter(lambda i: i!='NA', ncMean))
ncMean = list(map(lambda x : float(x), ncMean))
ncMean = statistics.mean(ncMean)
means.append(ncMean)

mMean = list(map(lambda x : x['ConvertedComp'], master))
mMean = list(filter(lambda i: i!='NA', mMean))
mMean = list(map(lambda x : float(x), mMean))
mMean = statistics.mean(mMean)
means.append(mMean)

naMean = list(map(lambda x : x['ConvertedComp'], na))
naMean = list(filter(lambda i: i!='NA', naMean))
naMean = list(map(lambda x : float(x), naMean))
naMean = statistics.mean(naMean)
means.append(naMean)

dMean = list(map(lambda x : x['ConvertedComp'], doctoral))
dMean = list(filter(lambda i: i!='NA', dMean))
dMean = list(map(lambda x : float(x), dMean))
dMean = statistics.mean(dMean)
means.append(dMean)

pMean = list(map(lambda x : x['ConvertedComp'], primary))
pMean = list(filter(lambda i: i!='NA', pMean))
pMean = list(map(lambda x : float(x), pMean))
pMean = statistics.mean(pMean)
means.append(pMean)

proMean = list(map(lambda x : x['ConvertedComp'], pro))
proMean = list(filter(lambda i: i!='NA', proMean))
proMean = list(map(lambda x : float(x), proMean))
proMean = statistics.mean(proMean)
means.append(proMean)

sMean = list(map(lambda x : x['ConvertedComp'], secondary))
sMean = list(filter(lambda i: i!='NA', sMean))
sMean = list(map(lambda x : float(x), sMean))
sMean = statistics.mean(sMean)
means.append(sMean)

cMean = list(map(lambda x : x['ConvertedComp'], college))
cMean = list(filter(lambda i: i!='NA', cMean))
cMean = list(map(lambda x : float(x), cMean))
cMean = statistics.mean(cMean)
means.append(cMean)

#sorting output and printing average salary per education level
output = list(map(lambda x,y: [y,x],categories,means))
output = sorted(output, reverse =True)
print("Average total earnings per education level:")
list(map(lambda i:print(i),output))
print()
# Out:
# Average total earnings per education level:
# [122849.05954465849, 'Other doctoral degree (Ph.D., Ed.D., etc.)']
# [114752.67973856209, 'Primary/elementary school']
# [107638.14531231481, 'Bachelor’s degree (B.A., B.S., B.Eng., etc.)']
# [106815.83219178082, 'Associate degree (A.A., A.S., etc.)']
# [104351.61688311688, 'I never completed any formal education']
# [103104.77549607752, 'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)']
# [97895.64170337739, 'Some college/university study without earning a degree']
# [83058.06514084506, 'NA']
# [79067.5613915416, 'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)']
# [72062.00419287212, 'Professional degree (JD, MD, etc.)']

# %%
#calculating number of people, and adding to list
people = []
people.append(len(associate))
people.append(len(bachelor))
people.append(len(notCompleted))
people.append(len(master))
people.append(len(na))
people.append(len(doctoral))
people.append(len(primary))
people.append(len(pro))
people.append(len(secondary))
people.append(len(college))

#sorting output and printing number of people per education level
output2 = list(map(lambda x,y: [y,x],categories,people))
output2 = sorted(output2, reverse =True)
print("# of people in survey per education level:")
list(map(lambda i:print(i),output2))
print()
# Out:
# # of people in survey per education level:
# [26542, 'Bachelor’s degree (B.A., B.S., B.Eng., etc.)']
# [13112, 'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)']
# [7239, 'Some college/university study without earning a degree']
# [7030, 'NA']
# [4771, 'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)']
# [1843, 'Associate degree (A.A., A.S., etc.)']
# [1690, 'Other doctoral degree (Ph.D., Ed.D., etc.)']
# [941, 'Primary/elementary school']
# [800, 'Professional degree (JD, MD, etc.)']
# [493, 'I never completed any formal education']

# %% [markdown]
# Note: While attempting to create a graph using matplot, the values using e+... would not be properly recognized as much larger values than the other ones in the list, causing the graph to not output correctly

# %% [markdown]
# When we run this search we can see that while a degree such as a Bachelor's, Doctoral, or Associate can earn you a lot of money, it is not the only option, as the average salary for those who only finished primary/elementary school was second on the list. We can also see that at the bottom of the ranking that (while still paying well), those who only finish highschool, drop out of post secondary, or only got a professional degree are paid signifigantly less than those with degrees. This does not seem to be heavily influenced by the number of respondents in each category, as the categories with fewer people typically had a much lower salary. However, these results are excluding the respondents who selected NA for their education level, as it is not possible to properly place them without figuring out their actual education level. Had we been able to do so the values may have changed, though the rankings would be unlikely to change drastically.
# With these results, we can conclude that with some exceptions, getting a higher level of education such as a Bachelor's or Doctoral degree is beneficial in getting a higher paying job as a software developer

# %% [markdown]
# Question 5: How do developers' salaries differ by location?

# %%
import pandas as pd
df = pd.DataFrame(data)

# %%
# Find the highest and lowest 5 average salaries per location.

locations = df[['Country', 'ConvertedComp']][df.ConvertedComp != 'NA']             # Make a pandas dataFrame with Country and Salary as the columns
locations['ConvertedComp'] = locations['ConvertedComp'].apply(lambda x : float(x)) # Convert all values to float
locations = pd.DataFrame(locations.groupby('Country')['ConvertedComp'].mean())     # Get the mean of all Salaries per Country
locations.reset_index(level=0, inplace=True)                                       # Reset index
locations = locations.sort_values(by = ['ConvertedComp'], ascending = False)       # Sort the values in descending order

locationsTop5 = round(locations.head(5), 2)                                        # Get top 5 locations and round to two decimals

# Print results
print(f'The top 5 locations by average salary are:\n\n {locationsTop5.to_string(index=False)}\n')

locationsBottom5 = round(locations.tail(5), 2)                                     # Get bottom 5 locations and round to two decimals

#Print results
print(f'The bottom 5 locations by average salary are:\n\n {locationsBottom5.to_string(index=False)}')
# Out:
# The top 5 locations by average salary are:
#
#                           Country  ConvertedComp
#                          Nomadic      310924.14
# Lao People's Democratic Republic      231275.25
#                    United States      208826.50
#                          Ireland      183000.74
#                      Afghanistan      148290.12
#
# The bottom 5 locations by average salary are:
#
#            Country  ConvertedComp
#          Cameroon         4450.6
#      Burkina Faso         3960.0
#             Sudan         3795.0
# Brunei Darussalam         2580.0
#           Lesotho           24.0

# %% [markdown]
# Potential Data Science
#
# Based on our findings and analysis, it is incredibly difficult to find any potential for a data science or machine learning project with this data set. This is due to the data being obtained directly from human beings, who are very complex in nature, instead of from code or values obtained elsewhere where an algorithm could be created to draw conclusions or could be used to teach a machine to notice specific patterns. Human beings tend to make choices based on an incredibly wide range of factors from mental, physical, social, and many others. While it might be possible to have a machine learn to notice patterns given this data, this dataset wasn’t made for that purpose, meaning that the results of such a project would likely be rather meaningless and not worth the effort it would take to accomplish such a task.

# %% [markdown]
# Conclusion
#
# Overall we were able to answer all of the analysis questions we set out in our proposal. We were however limited at times by the information given as we found that for certain row entries there were random values missing. Given that the data used was from a survey, most likely the questions posed were optional in nature. This created an extra layer of cleaning and formatting as we had to deal with many null and or 0 values that skewed with our graphs and analysis. From what we were able to use however, our results were what we expected. One thing that did catch our eyes though was that developers are constantly looking to improve their skills and progress in their fields. It seems as though that may be the reason for the competitive culture surrounding the tech industry. If we were to do the project again we’d love to find a data set where there weren't as many outliers and or blank values in the given data.
